# %% [markdown]
# # Actividad 9
# # 🔍 Parte 2: Análisis de Datasets
# Objetivo: Analizar datasets con Pandas, utilizando filtros y visualización con:
# * tablas
# * gráficos
# * mapas

# %% [markdown]
# ## Elegí un dataset
# * Realizar exploración básica

# %% [markdown]
# *  ### Avistajes de felinos en Argentina
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/5iC9FrYWiGi11d0
#     * Nombre del archivo: felinos_filtrado.csv
#     * Descargado y adaptado de: https://www.gbif.org/
#     * Descripción: describe los avistajes de felinos en peligro de extinción con ubicación, especie, fecha etc.
# * ### Áreas protegidas
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/Eqw1eAVC1pdefmb
#     * Descargado de: https://dnsg.ign.gob.ar/apps/api/v1/capas-sig/Geodesia+y+demarcaci%C3%B3n/L%C3%ADmites/area_protegida/csv*
#     * Página consultada: https://www.ign.gob.ar/NuestrasActividades/InformacionGeoespacial/CapasSIG
#     * Descripción: detalle de las áreas protegidas terrestres y marítimas
#     * Documento con detalle de los datos: https://archivos.linti.unlp.edu.ar/index.php/s/9LoXcqzxI8bDzbN
# * ### Aeropuertos Argentina
#     * Link para  descarga: https://archivos.linti.unlp.edu.ar/index.php/s/TYVZ5U6HC457M1k
#     * Nombre del archivo: ar-airports.csv
#     * Descargado de: https://ourairports.com/countries/AR/airports.csv
#     * Descripción: Aeropuertos de Argentina por tipo y localidad
# * ### Conectividad Argentina
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/3k2TO5sSzaAU6IY
#     * Nombre del archivo: Conectividad_Internet.csv
#     * Descargado de : https://datos.gob.ar/dataset/enacom-conectividad-al-servicio-internet/archivo/enacom_CONEC-AL-SERVI-DE-INTER_0
#     * Descripción: Describe las tecnologías disponibles en las localidades para acceder al servicio de Internet fijo y móvil
# * ### Precios combustibles
#     * [Link para descarga](https://archivos.linti.unlp.edu.ar/index.php/s/x0InilFLhgt1B1R).
#     * Descargado de: https://www.datos.gob.ar/dataset/energia-precios-surtidor---resolucion-3142016
#     * Descripción: Datos del Sistema en línea de información de precios de combustibles en surtidor, a través del cual los titulares de bocas de expendio de combustibles líquidos inscriptos en el registro creado por la resolución n° 1.102/2004 presentan la información relativa a precios de comercialización minorista dentro de las 8 (ocho) horas de producida una modificación en el precio en surtidor.
# * ### Ferrocarriles.
#     *  [Link para descarga](https://archivos.linti.unlp.edu.ar/index.php/s/Pr6vcKL9fxfmZoj)
#     * Descargado de :https://datos.transporte.gob.ar/dataset/cruces-ferroviarios
#     * Descripción: Cruces ferroviarios con respecto a la red vial nacional. Relevados por la Dirección Nacional de Vialidad. Año 2016.
#
#
# # ✅ Etapa 1: Exploración Básica (10 min)
# * Cantidad de filas y columans
# * Nombres de las columnas
# * Tipos de datos de las columnas
# * Ver las primeras 10 filas del dataset

# %%
import pandas as pd
import plotly.express as px
felinos = pd.read_csv('felinos_filtrado.csv')
lagos = pd.read_csv('lagos_arg.csv')

print("La cantidad de filas y columnas es: ")
felinos.shape
# Out:
# La cantidad de filas y columnas es:
# (2019, 19)

# %%
print("Los nombres de las columnas son: ")
felinos.columns
# Out:
# Los nombres de las columnas son:
# Index(['Unnamed: 0', 'kingdom', 'phylum', 'class', 'order', 'family', 'genus',
#        'species', 'locality', 'stateProvince', 'lat', 'lng', 'elevation',
#        'day', 'month', 'year', 'taxonKey', 'ScientificName',
#        'VernacularNames'],
#       dtype='object')

# %%
print("Los tipos de dato de las columnas son: ")
felinos.dtypes
# Out:
# Los tipos de dato de las columnas son:
# Unnamed: 0           int64
# kingdom             object
# phylum              object
# class               object
# order               object
# family              object
# genus               object
# species             object
# locality            object
# stateProvince       object
# lat                float64
# lng                float64
# elevation          float64
# day                float64
# month              float64
# year               float64
# taxonKey             int64
# ScientificName      object
# VernacularNames     object
# dtype: object

# %%
print("Las primeras 10 Filas del dataset son: ")
felinos.head(10)
# Out:
# Las primeras 10 Filas del dataset son:
#    Unnamed: 0   kingdom    phylum     class      order   family genus  \
# 0           0  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 1           1  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2           2  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 3           3  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 4           4  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 5           5  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 6           6  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 7           7  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 8           8  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 9           9  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
#
#              species                                         locality  \
# 0  Puma yagouaroundi  <p>Camino acceso al Destacamento Estero Poi</p>
# 1  Puma yagouaroundi             <p>Destacamento de Laguna Blanca</p>
# 2  Puma yagouaroundi                           <p>P.N. El Palmar.</p>
# 3  Puma yagouaroundi                  <p> RP Nº 86, Potrero Nº 15</p>
# 4  Puma yagouaroundi              <p> RP Nº 86, Potrero 2 Grande.</p>
# 5  Puma yagouaroundi                    <p>RP Nº 86, Potrero Nº 1</p>
# 6  Puma yagouaroundi   <p>Borde del Estero Santa Lucía, potrero 5</p>
# 7  Puma yagouaroundi                       <p>Potrero 3, pastizal</p>
# 8  Puma yagouaroundi                       <p>Pastizal potrero 14</p>
# 9  Puma yagouaroundi                      <p>Picada del potrero 6</p>
#
#   stateProvince       lat       lng  elevation   day  month    year  taxonKey  \
# 0       Formosa -25.12069 -58.18679        0.0  19.0    9.0  2006.0   2435146
# 1       Formosa -25.17201 -58.13073        0.0  20.0    9.0  2006.0   2435146
# 2    Entre Ríos -31.88614 -58.30839       24.0   8.0    9.0  2006.0   2435146
# 3    Corrientes -28.04421 -58.12875       69.0  29.0   11.0  2010.0   2435146
# 4    Corrientes -28.01889 -58.05301       74.0  17.0    6.0  2010.0   2435146
# 5    Corrientes -28.03358 -58.09678       69.0  12.0    4.0  2010.0   2435146
# 6    Corrientes -28.01706 -58.00131       72.0  27.0    9.0  2007.0   2435146
# 7    Corrientes -28.03820 -58.11760       70.0  19.0    9.0  2006.0   2435146
# 8    Corrientes -28.04910 -58.12297       68.0   3.0   12.0  2007.0   2435146
# 9    Corrientes -27.99967 -58.01706       71.0  30.0    8.0  2007.0   2435146
#
#       ScientificName                   VernacularNames
# 0  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 1  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 2  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 3  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 4  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 5  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 6  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 7  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 8  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 9  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi

# %% [markdown]
# ## ✅ Etapa 2: Análisis por temática(10 min)
# * Cada dataset se analizará según categorías correspondiente a los datos que lo conforman

# %% [markdown]
# El Dataset Avistamiento de Felinos Tiene Registros de felinos (Pumas, Leopardos y Panteras) Agrupados en su Reyno animal, Su tipo de ingesta, su especie y su sub especie, su ubicación y provincia, La latitud y longitud en la cual fueron registrados, el día, mes y año Junto con su nombre cientifico

# %%
felinos['genus'].unique
# Out:
# <bound method Series.unique of 0       Puma
# 1       Puma
# 2       Puma
# 3       Puma
# 4       Puma
#         ...
# 2014    Puma
# 2015    Puma
# 2016    Puma
# 2017    Puma
# 2018    Puma
# Name: genus, Length: 2019, dtype: object>

# %% [markdown]
# ## ✅ Etapa 3: Filtrar y Limpiar Datos (15 min)

# %%
lagos_max = lagos['Superficie (km²)'].max()
###La superficie maxima es 1435
provincia_max = lagos[lagos['Superficie (km²)'] == lagos_max]
provincia_max['Ubicación']
# Out:
# 0    Santa Cruz
# Name: Ubicación, dtype: object

# %%
cantidad_felinos = felinos[felinos['stateProvince'] == 'Santa Cruz']
cantidad_felinos = cantidad_felinos['genus']
cantidad_felinos.shape
# Out:
# (313,)

# %%
cantidad_Misiones = felinos[felinos['stateProvince'] == 'Misiones']
cantidad_Misiones.shape
# Out:
# (1253, 19)

# %%
felinos_EntreRios = felinos[felinos['stateProvince'] == 'Entre Ríos']
felinos_EntreRios['species'].value_counts()
# Out:
# Leopardus geoffroyi    7
# Puma yagouaroundi      4
# Name: species, dtype: int64

# %% [markdown]
# ## ✅ Etapa 4: Valores Nulos y Estadísticas (10 min)
# * Mostrar la composición de las columnas indicando aquellas con datos faltantes

# %%
felinos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2019 entries, 0 to 2018
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2019 non-null   int64
#  1   kingdom          2019 non-null   object
#  2   phylum           2019 non-null   object
#  3   class            2019 non-null   object
#  4   order            2019 non-null   object
#  5   family           2019 non-null   object
#  6   genus            2019 non-null   object
#  7   species          2019 non-null   object
#  8   locality         2011 non-null   object
#  9   stateProvince    2011 non-null   object
#  10  lat              2019 non-null   float64
#  11  lng              2019 non-null   float64
#  12  elevation        1998 non-null   float64
#  13  day              1992 non-null   float64
#  14  month            1992 non-null   float64
#  15  year             1992 non-null   float64
#  16  taxonKey         2019 non-null   int64
#  17  ScientificName   2019 non-null   object
#  18  VernacularNames  2019 non-null   object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 299.8+ KB

# %%
felinos.describe()
# Out:
#         Unnamed: 0          lat          lng    elevation          day  \
# count  2019.000000  2019.000000  2019.000000  1998.000000  1992.000000
# mean   1009.000000   -30.855484   -58.800594   208.971972    13.685241
# std     582.979416     8.848166     6.899827   207.365713     9.559133
# min       0.000000   -50.691590   -73.177620     0.000000     1.000000
# 25%     504.500000   -28.044210   -59.293030    73.000000     4.000000
# 50%    1009.000000   -25.789650   -54.459740   190.000000    14.000000
# 75%    1513.500000   -25.681880   -54.416105   246.000000    22.000000
# max    2018.000000   -23.711000   -53.760930  1654.000000    31.000000
#
#              month         year      taxonKey
# count  1992.000000  1992.000000  2.019000e+03
# mean      5.908635  2003.814759  2.703378e+06
# std       3.526136     6.346224  9.314685e+05
# min       1.000000  1937.000000  2.434924e+06
# 25%       2.000000  2003.000000  2.435099e+06
# 50%       6.000000  2005.000000  2.435099e+06
# 75%       9.000000  2008.000000  2.435146e+06
# max      12.000000  2012.000000  1.140149e+07

# %% [markdown]
# # ✅ Etapa 5: Visualización con Mapas (15 min)

# %% [markdown]
# *  ### Avistajes de felinos en Argentina
#     * **Mapa**: mostrar iconos de color según el tipo de "genus" .
# * ### Áreas protegidas
#     * **Mapa**: mostrar iconos de color según el tipo de área protegida definida en la columna "tap" que indica (Parque, Reserva, MonumentosNatural).
# * ### Aeropuertos Argentina
#     * **Mapa**: mostrar iconos de color según el tipo de aeropuerto: type
# * ### Conectividad Argentina
#     * **Mapa**: mostrar las localidades donde hay FIBRAOPTICA.
# * ### Precios combustibles
#     *  **Mapa**: mostrar los registros de las provincias de la Patagonia según "tipohorario".
# * ### Ferrocarriles.
#     * **Mapa**: mostrar las estaciones en el mapa según el tipo indicado en la columna "gna".

# %% [markdown]
# ## 📌 Paso 1.Generar un mapa **base** para luego agregar los puntos

# %%
import folium
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )
   
    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %%
mapa = generar_mapa()

# %% [markdown]
# ## 📌 Paso 2. Definir la función para  agregar los puntos

# %%
def agregar_marca_felinos(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['genus'],
        icon=folium.Icon()
        ).add_to(mapa)

# %% [markdown]
# ## 📌 Paso 3. Agrergar los puntos al mapa

# %%
felinos.apply(agregar_marca_felinos, axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2014    None
# 2015    None
# 2016    None
# 2017    None
# 2018    None
# Length: 2019, dtype: object

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_407da60879deabddb56dabf80ed97a22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_407da60879deabddb56dabf80ed97a22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_407da60879deabddb56dabf80ed97a22 = L.map(
#                 &quot;map_407da60879deabddb56dabf80ed97a22&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_407da60879deabddb56dabf80ed97a22);
#
#
#
#
#
#             var tile_layer_9e20eeaf14fb6fa4c24a4538037c705e = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e20eeaf14fb6fa4c24a4538037c705e.addTo(map_407da60879deabddb56dabf80ed97a22);
#
#
#             var marker_169359b753ed4b9f0d872d5a15f34499 = L.marker(
#                 [-25.12069, -58.18679],
#                 {
# }
#             ).addTo(map_407da60879deabddb56dabf80ed97a22);
#
#
#             var icon_6ebc84ac38d11fbd0be87cdef89977b1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6f2b1148f65ec8f36b9b84b08cb8c017 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddb17e9b4bc03e1148b54bd729166d47 = $(`&lt;div id=&quot;html_ddb17e9b4bc03e1148b54bd729166d47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puma&lt;/div&gt;`)[0];
#                 popup_6f2b1148f65ec8f36b9b84b08cb8c017.setContent(html_ddb17e9b4bc03e1148b54bd729166d47);
#
#
#
#         marker_169359b753ed4b9f0d872d5a15f34499.bindPopup(popup_6f2b1148f65ec8f36b9b84b08cb8c017)
#         ;
#
#
#
#
#                 marker_169359b753ed4b9f0d872d5a15f34499.setIcon(icon_6ebc84ac38d11fbd0be87cdef89977b1);
#
#
#             var marker_eb9b4b592fd3d08f90b1ebb1e895cc41 = L.marker(
#                 [-25.17201, -58.13073],
#                 {
# }
#             ).addTo(map_407da60879deabddb56dabf80ed97a22);
#
#
#             var icon_18211d7144c3b9dcaec47e2fdbffbc89 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_96b68a81b16c9a28cc705208c07d9059 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06ea8a04d2877cb7de63bbf5f118d20b = $(`&lt;div id=&quot;html_06ea8a04d2877cb7de63bbf5f118d20b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puma&lt;/div&gt;`)[0];
#                 popup_96b68a81b16c9a28cc705208c07d9059.setContent(html_06ea8a04d2877cb7de63bbf5f118d20b);
#
#
#
#         marker_eb9b4b592fd3d08f90b1ebb1e895cc41.bindPopup(popup_96b68a81b16c9a28cc705208c07d9059)
#         ;
#
#
#
#
#                 marker_eb9b4b592fd3d08f90b1ebb1e895cc41.setIcon(icon_18211d7144c3b9dcaec47e2fdbffbc89);
#
#
#             var marker_b6b061bb158b63d8b7c528a36beca162 = L.marker(
#                 [-31.88614, -58.30839],
#                 {
# }
#             ).addTo(map_407da60879deabddb56dabf80ed97a22);
#
#
#             var icon_cee2871cd30f21229c77b2d135a3263b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3575f7e4a5d456115735c3aba18741f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_406920baca03d8cdc76bd928751bffaa = $(`&lt;div id=&quot;html_406920baca03d8cdc76bd928751bffaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puma&lt;/div&gt;`)[0];
#                 popup_3575f7e4a5d456115735c3aba18741f6.setContent(html_406920baca03d8cdc76bd928751bffaa);
#
#
#
#         marker_b6b061bb158b63d8b7c528a36beca162.bin
